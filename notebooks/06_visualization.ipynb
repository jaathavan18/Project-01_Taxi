# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
import os

# Add the parent directory to the Python path
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..")))

# %%
import pandas as pd

from src.config import TRANSFORMED_DATA_DIR

features_and_targets = pd.read_parquet(TRANSFORMED_DATA_DIR / "tabular_data.parquet")

# %%
features = features_and_targets.iloc[:, :-1]
targets = features_and_targets["target"]

# %%
features[features['pickup_location_id']==43]
# Out:
#        rides_t-672  rides_t-671  rides_t-670  rides_t-669  rides_t-668  \
# 13817           92           81           29           15            4
# 13818            2            0            2            2            0
# 13819            1            0            0            0            1
# 13820            3            2            0            0            1
# 13821            6            0            0            1            0
# ...            ...          ...          ...          ...          ...
# 14149            3            0            1            0            1
# 14150            6            2            2            0            1
# 14151           20            7            2            0            3
# 14152           10            8            3            1            3
# 14153           19           10            1            2            2
#
#        rides_t-667  rides_t-666  rides_t-665  rides_t-664  rides_t-663  ...  \
# ...

# %%
from src.plot_utils import plot_aggregated_time_series
plot_aggregated_time_series(features, targets, row_id=13817)

# %%
location_features = features[features["pickup_location_id"] == 13817]
actual_target = targets.iloc[13817]
plot_aggregated_time_series(features, targets, row_id=13817)

# %%
print("Available index values:", features.index[:5])  # Print first 5 index values
print("Checking row_id exists:", 13835 in targets.index)  # Should return True/False
# Out:
# Available index values: RangeIndex(start=0, stop=5, step=1)
# Checking row_id exists: True
